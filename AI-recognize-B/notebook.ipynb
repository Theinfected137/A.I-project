# %%
import os
import zipfile
import scipy.io
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms
import matplotlib.pyplot as plt
from PIL import Image

# %%
extract_path = r"C:\Users\4534\Documents\A.I_project\AI-recognize-B\by_class"

os.makedirs(extract_path, exist_ok=True)

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    files = zip_ref.namelist()
    total_files = len(files)
    print(f"Extraindo {total_files} arquivos...")

    for i, file in enumerate(files, 1):
        zip_ref.extract(file, extract_path)
        percent = (i / total_files) * 100
        print(f"Extraindo: {file} ({percent:.2f}%)", end='\r')

print("\nExtração concluída!")

# Listar arquivos extraídos
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[37], line 6
#       2 extract_path = r"C:\Users\4534\Documents\A.I_project\AI-recognize-B\by_class"
#       4 os.makedirs(extract_path, exist_ok=True)
# ----> 6 with zipfile.ZipFile(zip_path, 'r') as zip_ref:
#       7     files = zip_ref.namelist()
#       8     total_files = len(files)
#
# File c:\Users\4534\AppData\Local\Python\pythoncore-3.14-64\Lib\zipfile\__init__.py:1471, in ZipFile.__init__(self, file, mode, compression, allowZip64, compresslevel, strict_timestamps, metadata_encoding)
#    1469 try:
#    1470     if mode == 'r':
# -> 1471         self._RealGetContents()
#    1472     elif mode in ('w', 'x'):
#    1473         # set the modified flag so central directory gets written
#    1474         # even if no files are added to the archive
#    1475         self._didModify = True
#
# File c:\Users\4534\AppData\Local\Python\pythoncore-3.14-64\Lib\zipfile\__init__.py:1564, in ZipFile._RealGetContents(self)
#    1562 if self.debug > 2:
#    1563     print(centdir)
# -> 1564 filename = fp.read(centdir[_CD_FILENAME_LENGTH])
#    1565 orig_filename_crc = crc32(filename)
#    1566 flags = centdir[_CD_FLAG_BITS]
#
# KeyboardInterrupt:

# %%
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[38], line 9
#       6             print("Arquivo .mat encontrado:", mat_file)
#       8 if mat_file is None:
# ----> 9     raise FileNotFoundError("Nenhum arquivo .mat encontrado no ZIP.")
#
# FileNotFoundError: Nenhum arquivo .mat encontrado no ZIP.
